# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | qaanaaq
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | cabo san lucas
# Processing Record 4 of Set 1 | wakkanai
# Processing Record 5 of Set 1 | broome
# Processing Record 6 of Set 1 | komsomolskiy
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | saskylakh
# Processing Record 12 of Set 1 | lompoc
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | ostrovnoy
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | burica
# City not found. Skipping...
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | kapenguria
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 1 | constitucion
# Processing Record 24 of Set 1 | villanueva
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | is
# City not found. Skipping...
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | rio grande
# Processing Record 29 of Set 1 | atlantic city
# Processing Record 30 of Set 1 | kieta
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | kamennomostskoye
# Processing Record 34 of Set 1 | nanortalik
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | san rafael
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | saint-leu
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobyo
# Processing Record 50 of Set 1 | santa cruz
# Processing Record 1 of Set 2 | torbay
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | vitorino freire
# Processing Record 4 of Set 2 | norman wells
# Processing Record 5 of Set 2 | boende
# Processing Record 6 of Set 2 | biloela
# Processing Record 7 of Set 2 | lokosovo
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | amapa
# Processing Record 10 of Set 2 | taoudenni
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | gorontalo
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | auki
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | lagoa
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | salalah
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | porbandar
# Processing Record 21 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 2 | avera
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | thinadhoo
# Processing Record 25 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 2 | chunskiy
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | saint-joseph
# Processing Record 29 of Set 2 | tongliao
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | ponta do sol
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | alta floresta
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | leningradskiy
# Processing Record 38 of Set 2 | hastings
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | tautira
# Processing Record 43 of Set 2 | turayf
# Processing Record 44 of Set 2 | el retorno
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | asyut
# Processing Record 47 of Set 2 | umba
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | sangar
# Processing Record 50 of Set 2 | grants
# Processing Record 1 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 2 of Set 3 | ambatondrazaka
# Processing Record 3 of Set 3 | mocuba
# Processing Record 4 of Set 3 | daoukro
# Processing Record 5 of Set 3 | bonavista
# Processing Record 6 of Set 3 | tadine
# Processing Record 7 of Set 3 | sao joao da barra
# Processing Record 8 of Set 3 | makakilo city
# Processing Record 9 of Set 3 | andros
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | araouane
# Processing Record 12 of Set 3 | vernon
# Processing Record 13 of Set 3 | thanh hoa
# Processing Record 14 of Set 3 | bandar
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | ulcinj
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | kargasok
# Processing Record 20 of Set 3 | gryfino
# Processing Record 21 of Set 3 | saint anthony
# Processing Record 22 of Set 3 | bac lieu
# Processing Record 23 of Set 3 | bodaybo
# Processing Record 24 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 3 | tecpan
# Processing Record 26 of Set 3 | keetmanshoop
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | erenhot
# Processing Record 29 of Set 3 | hauge
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 3 | millinocket
# Processing Record 34 of Set 3 | buchanan
# Processing Record 35 of Set 3 | shenjiamen
# Processing Record 36 of Set 3 | berkakit
# Processing Record 37 of Set 3 | maldonado
# Processing Record 38 of Set 3 | bocana de paiwas
# Processing Record 39 of Set 3 | denpasar
# Processing Record 40 of Set 3 | uvalde
# Processing Record 41 of Set 3 | panaba
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | fairbanks
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | thai binh
# Processing Record 46 of Set 3 | san cristobal
# Processing Record 47 of Set 3 | butaritari
# Processing Record 48 of Set 3 | tromso
# Processing Record 49 of Set 3 | umm kaddadah
# Processing Record 50 of Set 3 | sitka
# Processing Record 1 of Set 4 | klaksvik
# Processing Record 2 of Set 4 | mana
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | glenwood springs
# Processing Record 5 of Set 4 | mitchell
# Processing Record 6 of Set 4 | kawalu
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | chabahar
# Processing Record 9 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 10 of Set 4 | emerald
# Processing Record 11 of Set 4 | kunming
# Processing Record 12 of Set 4 | cantagalo
# Processing Record 13 of Set 4 | mar del plata
# Processing Record 14 of Set 4 | vao
# Processing Record 15 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 4 | vila franca do campo
# Processing Record 17 of Set 4 | rio gallegos
# Processing Record 18 of Set 4 | upernavik
# Processing Record 19 of Set 4 | ottawa
# Processing Record 20 of Set 4 | pangnirtung
# Processing Record 21 of Set 4 | nouadhibou
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | port hardy
# Processing Record 24 of Set 4 | san pedro
# Processing Record 25 of Set 4 | evensk
# Processing Record 26 of Set 4 | kodiak
# Processing Record 27 of Set 4 | esna
# Processing Record 28 of Set 4 | hohhot
# Processing Record 29 of Set 4 | marawi
# Processing Record 30 of Set 4 | port lincoln
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | kapaa
# Processing Record 33 of Set 4 | riyadh
# Processing Record 34 of Set 4 | aldan
# Processing Record 35 of Set 4 | tulcea
# Processing Record 36 of Set 4 | ancud
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | amurzet
# Processing Record 39 of Set 4 | teya
# Processing Record 40 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 4 | nueva loja
# Processing Record 42 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 4 | atar
# Processing Record 44 of Set 4 | dodge city
# Processing Record 45 of Set 4 | san patricio
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | seoul
# Processing Record 48 of Set 4 | dandong
# Processing Record 49 of Set 4 | tupiza
# Processing Record 50 of Set 4 | cravo norte
# Processing Record 1 of Set 5 | theodoriana
# Processing Record 2 of Set 5 | dickinson
# Processing Record 3 of Set 5 | tiksi
# Processing Record 4 of Set 5 | atambua
# Processing Record 5 of Set 5 | beringovskiy
# Processing Record 6 of Set 5 | berlevag
# Processing Record 7 of Set 5 | high level
# Processing Record 8 of Set 5 | bengkulu
# Processing Record 9 of Set 5 | labuhan
# Processing Record 10 of Set 5 | baykit
# Processing Record 11 of Set 5 | nicoya
# Processing Record 12 of Set 5 | shimoda
# Processing Record 13 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 5 | klyuchi
# Processing Record 15 of Set 5 | clemencia
# Processing Record 16 of Set 5 | mouila
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | bandarbeyla
# Processing Record 19 of Set 5 | ponta delgada
# Processing Record 20 of Set 5 | fria
# Processing Record 21 of Set 5 | orbetello
# Processing Record 22 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 5 | puerto ayora
# Processing Record 24 of Set 5 | terre haute
# Processing Record 25 of Set 5 | bonthe
# Processing Record 26 of Set 5 | kalagarh
# Processing Record 27 of Set 5 | orissaare
# Processing Record 28 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | boysun
# Processing Record 31 of Set 5 | basco
# Processing Record 32 of Set 5 | lavrentiya
# Processing Record 33 of Set 5 | maniitsoq
# Processing Record 34 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 35 of Set 5 | roebourne
# Processing Record 36 of Set 5 | ukiah
# Processing Record 37 of Set 5 | matara
# Processing Record 38 of Set 5 | esperance
# Processing Record 39 of Set 5 | bubaque
# Processing Record 40 of Set 5 | port alfred
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | sam phran
# Processing Record 43 of Set 5 | la peca
# Processing Record 44 of Set 5 | saint-philippe
# Processing Record 45 of Set 5 | makat
# Processing Record 46 of Set 5 | saint-pierre
# Processing Record 47 of Set 5 | mehamn
# Processing Record 48 of Set 5 | belaya gora
# Processing Record 49 of Set 5 | pandan
# Processing Record 50 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 6 | moree
# Processing Record 2 of Set 6 | dekar
# Processing Record 3 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 6 | ahipara
# Processing Record 5 of Set 6 | srednekolymsk
# Processing Record 6 of Set 6 | puerto madero
# Processing Record 7 of Set 6 | kaniama
# Processing Record 8 of Set 6 | faanui
# Processing Record 9 of Set 6 | thompson
# Processing Record 10 of Set 6 | olinda
# Processing Record 11 of Set 6 | nador
# Processing Record 12 of Set 6 | xiaoweizhai
# Processing Record 13 of Set 6 | port moresby
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | akyab
# Processing Record 16 of Set 6 | sinnamary
# Processing Record 17 of Set 6 | nuevitas
# Processing Record 18 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 6 | pevek
# Processing Record 20 of Set 6 | talara
# Processing Record 21 of Set 6 | huntington
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | viedma
# Processing Record 24 of Set 6 | narasannapeta
# Processing Record 25 of Set 6 | aksu
# Processing Record 26 of Set 6 | merauke
# Processing Record 27 of Set 6 | megion
# Processing Record 28 of Set 6 | la rioja
# Processing Record 29 of Set 6 | sarahan
# Processing Record 30 of Set 6 | guerrero negro
# Processing Record 31 of Set 6 | hovd
# Processing Record 32 of Set 6 | buala
# Processing Record 33 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 6 | tezu
# Processing Record 35 of Set 6 | calvinia
# Processing Record 36 of Set 6 | leshukonskoye
# Processing Record 37 of Set 6 | kasungu
# Processing Record 38 of Set 6 | walvis bay
# Processing Record 39 of Set 6 | margate
# Processing Record 40 of Set 6 | bredasdorp
# Processing Record 41 of Set 6 | gardan diwal
# City not found. Skipping...
# Processing Record 42 of Set 6 | mazatlan
# Processing Record 43 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 6 | kosa
# Processing Record 46 of Set 6 | kwinana
# Processing Record 47 of Set 6 | puerto escondido
# Processing Record 48 of Set 6 | zhigansk
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | yulara
# Processing Record 1 of Set 7 | egvekinot
# Processing Record 2 of Set 7 | kamenka
# Processing Record 3 of Set 7 | kavaratti
# Processing Record 4 of Set 7 | cap malheureux
# Processing Record 5 of Set 7 | irbeyskoye
# Processing Record 6 of Set 7 | mount isa
# Processing Record 7 of Set 7 | kaoma
# Processing Record 8 of Set 7 | pomabamba
# Processing Record 9 of Set 7 | aklavik
# Processing Record 10 of Set 7 | stornoway
# Processing Record 11 of Set 7 | rorvik
# Processing Record 12 of Set 7 | ridgecrest
# Processing Record 13 of Set 7 | ayorou
# Processing Record 14 of Set 7 | shimanovsk
# Processing Record 15 of Set 7 | homer
# Processing Record 16 of Set 7 | cabra
# Processing Record 17 of Set 7 | izberbash
# Processing Record 18 of Set 7 | jimma
# Processing Record 19 of Set 7 | igarka
# Processing Record 20 of Set 7 | banda aceh
# Processing Record 21 of Set 7 | kefamenanu
# Processing Record 22 of Set 7 | hillsborough
# Processing Record 23 of Set 7 | kununurra
# Processing Record 24 of Set 7 | okitipupa
# Processing Record 25 of Set 7 | sayat
# Processing Record 26 of Set 7 | san matias
# Processing Record 27 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 7 | dingle
# Processing Record 29 of Set 7 | barahona
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | georgetown
# Processing Record 32 of Set 7 | houston
# Processing Record 33 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 7 | longonjo
# Processing Record 35 of Set 7 | villa maria
# Processing Record 36 of Set 7 | marrakesh
# Processing Record 37 of Set 7 | conceicao do araguaia
# Processing Record 38 of Set 7 | parrita
# Processing Record 39 of Set 7 | nikolayevka
# Processing Record 40 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 7 | woodward
# Processing Record 42 of Set 7 | westport
# Processing Record 43 of Set 7 | xining
# Processing Record 44 of Set 7 | loa janan
# Processing Record 45 of Set 7 | dolores
# Processing Record 46 of Set 7 | cherskiy
# Processing Record 47 of Set 7 | shancheng
# Processing Record 48 of Set 7 | husavik
# Processing Record 49 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 7 | half moon bay
# Processing Record 1 of Set 8 | qui nhon
# Processing Record 2 of Set 8 | roma
# Processing Record 3 of Set 8 | moiyabana
# City not found. Skipping...
# Processing Record 4 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 5 of Set 8 | axim
# Processing Record 6 of Set 8 | henties bay
# Processing Record 7 of Set 8 | dahuk
# Processing Record 8 of Set 8 | mongomo
# Processing Record 9 of Set 8 | fortuna
# Processing Record 10 of Set 8 | lishu
# Processing Record 11 of Set 8 | piacabucu
# Processing Record 12 of Set 8 | pacific grove
# Processing Record 13 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 8 | cefalu
# Processing Record 15 of Set 8 | tomatlan
# Processing Record 16 of Set 8 | honiara
# Processing Record 17 of Set 8 | kashi
# Processing Record 18 of Set 8 | santa cruz das palmeiras
# Processing Record 19 of Set 8 | los llanos de aridane
# Processing Record 20 of Set 8 | baruun-urt
# Processing Record 21 of Set 8 | duz
# City not found. Skipping...
# Processing Record 22 of Set 8 | santa cruz do capibaribe
# Processing Record 23 of Set 8 | qasigiannguit
# Processing Record 24 of Set 8 | bima
# Processing Record 25 of Set 8 | senmonorom
# City not found. Skipping...
# Processing Record 26 of Set 8 | sokolo
# Processing Record 27 of Set 8 | khandbari
# Processing Record 28 of Set 8 | terrace
# Processing Record 29 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 8 | bowling green
# Processing Record 31 of Set 8 | hoshcha
# Processing Record 32 of Set 8 | gwadar
# Processing Record 33 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 8 | mingaora
# Processing Record 35 of Set 8 | cassilandia
# Processing Record 36 of Set 8 | zhangye
# Processing Record 37 of Set 8 | tambura
# Processing Record 38 of Set 8 | nagorsk
# Processing Record 39 of Set 8 | parabel
# Processing Record 40 of Set 8 | atagay
# Processing Record 41 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 42 of Set 8 | klaeng
# Processing Record 43 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 8 | muros
# Processing Record 45 of Set 8 | broken hill
# Processing Record 46 of Set 8 | anloga
# Processing Record 47 of Set 8 | babu
# Processing Record 48 of Set 8 | caceres
# Processing Record 49 of Set 8 | sampang
# Processing Record 50 of Set 8 | kirkuk
# Processing Record 1 of Set 9 | tisul
# Processing Record 2 of Set 9 | buraydah
# Processing Record 3 of Set 9 | serra talhada
# Processing Record 4 of Set 9 | brawley
# Processing Record 5 of Set 9 | luanda
# Processing Record 6 of Set 9 | namibe
# Processing Record 7 of Set 9 | khandyga
# Processing Record 8 of Set 9 | ulladulla
# Processing Record 9 of Set 9 | darayya
# Processing Record 10 of Set 9 | kavieng
# Processing Record 11 of Set 9 | novaya igirma
# Processing Record 12 of Set 9 | ughelli
# Processing Record 13 of Set 9 | russell
# Processing Record 14 of Set 9 | dzhebariki-khaya
# Processing Record 15 of Set 9 | williams lake
# Processing Record 16 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 9 | nha trang
# Processing Record 18 of Set 9 | morden
# Processing Record 19 of Set 9 | kahului
# Processing Record 20 of Set 9 | caluquembe
# Processing Record 21 of Set 9 | sao filipe
# Processing Record 22 of Set 9 | menongue
# Processing Record 23 of Set 9 | zastron
# Processing Record 24 of Set 9 | narowal
# Processing Record 25 of Set 9 | biltine
# Processing Record 26 of Set 9 | polunochnoye
# Processing Record 27 of Set 9 | winnemucca
# Processing Record 28 of Set 9 | lorengau
# Processing Record 29 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 9 | nantucket
# Processing Record 31 of Set 9 | karanja
# Processing Record 32 of Set 9 | kamaishi
# Processing Record 33 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 9 | vanimo
# Processing Record 35 of Set 9 | hay river
# Processing Record 36 of Set 9 | lubao
# Processing Record 37 of Set 9 | horodnytsya
# Processing Record 38 of Set 9 | nabire
# Processing Record 39 of Set 9 | san isidro
# Processing Record 40 of Set 9 | sept-iles
# Processing Record 41 of Set 9 | sao gabriel da cachoeira
# Processing Record 42 of Set 9 | arroio grande
# Processing Record 43 of Set 9 | okhotsk
# Processing Record 44 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 9 | trelew
# Processing Record 46 of Set 9 | port-gentil
# Processing Record 47 of Set 9 | tessalit
# Processing Record 48 of Set 9 | urumqi
# Processing Record 49 of Set 9 | gigmoto
# Processing Record 50 of Set 9 | longyearbyen
# Processing Record 1 of Set 10 | batagay-alyta
# Processing Record 2 of Set 10 | ilhabela
# Processing Record 3 of Set 10 | nalut
# Processing Record 4 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 5 of Set 10 | chifeng
# Processing Record 6 of Set 10 | sioux lookout
# Processing Record 7 of Set 10 | champerico
# Processing Record 8 of Set 10 | huaibei
# Processing Record 9 of Set 10 | tabou
# Processing Record 10 of Set 10 | harbour breton
# Processing Record 11 of Set 10 | coihaique
# Processing Record 12 of Set 10 | birjand
# Processing Record 13 of Set 10 | bafoulabe
# Processing Record 14 of Set 10 | xichang
# Processing Record 15 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 10 | marsa matruh
# Processing Record 17 of Set 10 | greeneville
# Processing Record 18 of Set 10 | obeliai
# Processing Record 19 of Set 10 | aras
# Processing Record 20 of Set 10 | dubenskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | mudgee
# Processing Record 22 of Set 10 | shahrud
# Processing Record 23 of Set 10 | iquitos
# Processing Record 24 of Set 10 | lithakia
# Processing Record 25 of Set 10 | bhuban
# Processing Record 26 of Set 10 | elk plain
# Processing Record 27 of Set 10 | minuri
# Processing Record 28 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 29 of Set 10 | richards bay
# Processing Record 30 of Set 10 | yarim
# Processing Record 31 of Set 10 | uchiza
# Processing Record 32 of Set 10 | ourossogui
# Processing Record 33 of Set 10 | ayios nikolaos
# Processing Record 34 of Set 10 | saint simons
# Processing Record 35 of Set 10 | kodinsk
# Processing Record 36 of Set 10 | pozo colorado
# Processing Record 37 of Set 10 | general roca
# Processing Record 38 of Set 10 | bara
# Processing Record 39 of Set 10 | hamilton
# Processing Record 40 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 41 of Set 10 | cayenne
# Processing Record 42 of Set 10 | ballina
# Processing Record 43 of Set 10 | shingu
# Processing Record 44 of Set 10 | karpogory
# Processing Record 45 of Set 10 | spring valley
# Processing Record 46 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 10 | tacna
# Processing Record 48 of Set 10 | prabumulih
# Processing Record 49 of Set 10 | melekhovskaya
# City not found. Skipping...
# Processing Record 50 of Set 10 | epiniana
# Processing Record 1 of Set 11 | nome
# Processing Record 2 of Set 11 | kutum
# Processing Record 3 of Set 11 | triunfo
# Processing Record 4 of Set 11 | tucupita
# Processing Record 5 of Set 11 | lahaina
# Processing Record 6 of Set 11 | pouembout
# Processing Record 7 of Set 11 | zonguldak
# Processing Record 8 of Set 11 | dryden
# Processing Record 9 of Set 11 | harper
# Processing Record 10 of Set 11 | bereda
# Processing Record 11 of Set 11 | buribay
# Processing Record 12 of Set 11 | kropotkin
# Processing Record 13 of Set 11 | sunrise manor
# Processing Record 14 of Set 11 | ust-kulom
# Processing Record 15 of Set 11 | zyryanka
# Processing Record 16 of Set 11 | hofn
# Processing Record 17 of Set 11 | pijijiapan
# Processing Record 18 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 11 | road town
# Processing Record 20 of Set 11 | lucapa
# Processing Record 21 of Set 11 | timizart
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | goderich
# Processing Record 24 of Set 11 | senanga
# Processing Record 25 of Set 11 | azare
# Processing Record 26 of Set 11 | katsuura
# Processing Record 27 of Set 11 | ossora
# Processing Record 28 of Set 11 | zabaykalsk
# Processing Record 29 of Set 11 | mwense
# Processing Record 30 of Set 11 | kotma
# Processing Record 31 of Set 11 | san andres
# Processing Record 32 of Set 11 | maragogi
# Processing Record 33 of Set 11 | yumen
# Processing Record 34 of Set 11 | madison
# Processing Record 35 of Set 11 | linjiang
# Processing Record 36 of Set 11 | puerto suarez
# Processing Record 37 of Set 11 | najran
# Processing Record 38 of Set 11 | tabat
# Processing Record 39 of Set 11 | sauda
# Processing Record 40 of Set 11 | nanakuli
# Processing Record 41 of Set 11 | mattru
# Processing Record 42 of Set 11 | college
# Processing Record 43 of Set 11 | iqaluit
# Processing Record 44 of Set 11 | talnakh
# Processing Record 45 of Set 11 | whitehorse
# Processing Record 46 of Set 11 | faya
# Processing Record 47 of Set 11 | robertson
# Processing Record 48 of Set 11 | kuytun
# Processing Record 49 of Set 11 | north bend
# Processing Record 50 of Set 11 | yakovlevo
# Processing Record 1 of Set 12 | ola
# Processing Record 2 of Set 12 | nahariyya
# Processing Record 3 of Set 12 | kungurtug
# Processing Record 4 of Set 12 | padang
# Processing Record 5 of Set 12 | marovoay
# Processing Record 6 of Set 12 | oksfjord
# Processing Record 7 of Set 12 | paamiut
# Processing Record 8 of Set 12 | madisonville
# Processing Record 9 of Set 12 | karaman
# Processing Record 10 of Set 12 | chicama
# Processing Record 11 of Set 12 | isoka
# Processing Record 12 of Set 12 | khed brahma
# Processing Record 13 of Set 12 | antalaha
# Processing Record 14 of Set 12 | mayo
# Processing Record 15 of Set 12 | ende
# Processing Record 16 of Set 12 | khonsar
# City not found. Skipping...
# Processing Record 17 of Set 12 | minas
# Processing Record 18 of Set 12 | statesboro
# Processing Record 19 of Set 12 | ye
# City not found. Skipping...
# Processing Record 20 of Set 12 | lusambo
# Processing Record 21 of Set 12 | asosa
# Processing Record 22 of Set 12 | taltal
# Processing Record 23 of Set 12 | colesberg
# Processing Record 24 of Set 12 | zhanaozen
# Processing Record 25 of Set 12 | celestun
# Processing Record 26 of Set 12 | asau
# Processing Record 27 of Set 12 | pyay
# Processing Record 28 of Set 12 | praia
# Processing Record 29 of Set 12 | hemsedal
# Processing Record 30 of Set 12 | bad wildbad
# Processing Record 31 of Set 12 | ondjiva
# Processing Record 32 of Set 12 | mount gambier
# Processing Record 33 of Set 12 | jaynagar
# Processing Record 34 of Set 12 | lata
# Processing Record 35 of Set 12 | santa fe
# Processing Record 36 of Set 12 | trairi
# Processing Record 37 of Set 12 | vizinga
# Processing Record 38 of Set 12 | san ramon
# Processing Record 39 of Set 12 | jalna
# Processing Record 40 of Set 12 | youkounkoun
# Processing Record 41 of Set 12 | serenje
# Processing Record 42 of Set 12 | bilibino
# Processing Record 43 of Set 12 | oborniki
# Processing Record 44 of Set 12 | miri
# Processing Record 45 of Set 12 | weatherford
# Processing Record 46 of Set 12 | prince albert
# Processing Record 47 of Set 12 | laguna
# Processing Record 48 of Set 12 | honningsvag
# Processing Record 49 of Set 12 | fomboni
# Processing Record 50 of Set 12 | highland
# Processing Record 1 of Set 13 | rathenow
# Processing Record 2 of Set 13 | baijiantan
# Processing Record 3 of Set 13 | muscat
# Processing Record 4 of Set 13 | dunedin
# Processing Record 5 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 13 | quatre cocos
# Processing Record 7 of Set 13 | kudahuvadhoo
# Processing Record 8 of Set 13 | amahai
# Processing Record 9 of Set 13 | deputatskiy
# Processing Record 10 of Set 13 | kysyl-syr
# Processing Record 11 of Set 13 | butembo
# Processing Record 12 of Set 13 | asamankese
# Processing Record 13 of Set 13 | malanje
# Processing Record 14 of Set 13 | miyako
# Processing Record 15 of Set 13 | samana
# Processing Record 16 of Set 13 | yaan
# Processing Record 17 of Set 13 | oussouye
# Processing Record 18 of Set 13 | mangan
# Processing Record 19 of Set 13 | san quintin
# Processing Record 20 of Set 13 | donskoye
# Processing Record 21 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 13 | kintinku
# Processing Record 23 of Set 13 | moose factory
# Processing Record 24 of Set 13 | havre-saint-pierre
# Processing Record 25 of Set 13 | vallenar
# Processing Record 26 of Set 13 | salinopolis
# Processing Record 27 of Set 13 | vila velha
# Processing Record 28 of Set 13 | vokhma
# Processing Record 29 of Set 13 | khorramshahr
# Processing Record 30 of Set 13 | ormara
# Processing Record 31 of Set 13 | ust-barguzin
# Processing Record 32 of Set 13 | lashio
# Processing Record 33 of Set 13 | shache
# Processing Record 34 of Set 13 | mtwara
# Processing Record 35 of Set 13 | jega
# Processing Record 36 of Set 13 | barinas
# Processing Record 37 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 38 of Set 13 | leh
# Processing Record 39 of Set 13 | rawson
# Processing Record 40 of Set 13 | centralia
# Processing Record 41 of Set 13 | qaqortoq
# Processing Record 42 of Set 13 | usinsk
# Processing Record 43 of Set 13 | maumere
# Processing Record 44 of Set 13 | mizusawa
# Processing Record 45 of Set 13 | gat
# Processing Record 46 of Set 13 | suntar
# Processing Record 47 of Set 13 | marzuq
# Processing Record 48 of Set 13 | andros town
# Processing Record 49 of Set 13 | te anau
# Processing Record 50 of Set 13 | yichang
# Processing Record 1 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 14 | dwarka
# Processing Record 3 of Set 14 | poum
# Processing Record 4 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 14 | pemba
# Processing Record 6 of Set 14 | priargunsk
# Processing Record 7 of Set 14 | ler
# Processing Record 8 of Set 14 | carauari
# Processing Record 9 of Set 14 | portland
# Processing Record 10 of Set 14 | havoysund
# Processing Record 11 of Set 14 | romuli
# Processing Record 12 of Set 14 | male
# Processing Record 13 of Set 14 | bathsheba
# Processing Record 14 of Set 14 | meulaboh
# Processing Record 15 of Set 14 | yerbogachen
# Processing Record 16 of Set 14 | beloha
# Processing Record 17 of Set 14 | canitas
# City not found. Skipping...
# Processing Record 18 of Set 14 | oistins
# Processing Record 19 of Set 14 | xam nua
# Processing Record 20 of Set 14 | savonlinna
# Processing Record 21 of Set 14 | anzio
# Processing Record 22 of Set 14 | mitzic
# Processing Record 23 of Set 14 | mandalgovi
# Processing Record 24 of Set 14 | basoko
# Processing Record 25 of Set 14 | opuwo
# Processing Record 26 of Set 14 | pantai remis
# Processing Record 27 of Set 14 | kaitangata
# Processing Record 28 of Set 14 | bo phloi
# Processing Record 29 of Set 14 | do gonbadan
# Processing Record 30 of Set 14 | pervomayskoye
# Processing Record 31 of Set 14 | christchurch
# Processing Record 32 of Set 14 | tateyama
# Processing Record 33 of Set 14 | porto velho
# Processing Record 34 of Set 14 | oschatz
# Processing Record 35 of Set 14 | samarai
# Processing Record 36 of Set 14 | caravelas
# Processing Record 37 of Set 14 | pousat
# City not found. Skipping...
# Processing Record 38 of Set 14 | arlit
# Processing Record 39 of Set 14 | necochea
# Processing Record 40 of Set 14 | monticello
# Processing Record 41 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 42 of Set 14 | papetoai
# Processing Record 43 of Set 14 | ternate
# Processing Record 44 of Set 14 | maceio
# Processing Record 45 of Set 14 | haapiti
# Processing Record 46 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 47 of Set 14 | fort frances
# Processing Record 48 of Set 14 | siavonga
# Processing Record 49 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 14 | asmar
# Processing Record 1 of Set 15 | bayir
# Processing Record 2 of Set 15 | brae
# Processing Record 3 of Set 15 | tiznit
# Processing Record 4 of Set 15 | luocheng
# Processing Record 5 of Set 15 | pochutla
# Processing Record 6 of Set 15 | gohad
# Processing Record 7 of Set 15 | brownwood
# Processing Record 8 of Set 15 | sabang
# Processing Record 9 of Set 15 | kirakira
# Processing Record 10 of Set 15 | morlaix
# Processing Record 11 of Set 15 | naze
# Processing Record 12 of Set 15 | wassenaar
# Processing Record 13 of Set 15 | oktyabrskiy
# Processing Record 14 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 15 | waterloo
# Processing Record 16 of Set 15 | isangel
# Processing Record 17 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | flinders
# Processing Record 19 of Set 15 | chapais
# Processing Record 20 of Set 15 | hirara
# Processing Record 21 of Set 15 | alice springs
# Processing Record 22 of Set 15 | along
# Processing Record 23 of Set 15 | puerto baquerizo moreno
# Processing Record 24 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 15 | gobabis
# Processing Record 26 of Set 15 | sibay
# Processing Record 27 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 15 | qena
# Processing Record 29 of Set 15 | nemuro
# Processing Record 30 of Set 15 | muli
# Processing Record 31 of Set 15 | aljezur
# Processing Record 32 of Set 15 | bansi
# Processing Record 33 of Set 15 | gouyave
# Processing Record 34 of Set 15 | kurumkan
# Processing Record 35 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 15 | port keats
# Processing Record 37 of Set 15 | northam
# Processing Record 38 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 15 | beyneu
# Processing Record 40 of Set 15 | tornio
# Processing Record 41 of Set 15 | sobolevo
# Processing Record 42 of Set 15 | mayskiy
# Processing Record 43 of Set 15 | corn island
# Processing Record 44 of Set 15 | mitu
# Processing Record 45 of Set 15 | ardesen
# Processing Record 46 of Set 15 | serpa
# Processing Record 47 of Set 15 | olafsvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 674

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Qaanaaq  77.4840  -69.3632      7.03        91          98
# 1       Jamestown  42.0970  -79.2353     40.59        89         100
# 2  Cabo San Lucas  22.8909 -109.9124     85.17        67          34
# 3        Wakkanai  45.4094  141.6739     48.42        55         100
# 4          Broome  42.2506  -75.8330     48.15        63         100
# 5    Komsomolskiy  40.4272   71.7189     56.12        76          75
# 6        Saldanha -33.0117   17.9442     59.05        95          72
# 7      Chokurdakh  70.6333  147.9167      4.37        98          97
# 8       Saskylakh  71.9167  114.0833     18.90        86         100
# 9          Lompoc  34.6391 -120.4579     81.79        56           0
#
#    Wind Speed Country Current Description
# 0        4.05      GL     overcast clouds
# 1       17.27      US     overcast clouds
# 2        5.21      MX    scattered clouds
# 3       24.79      JP     overcast clouds
# 4        9.22      US     overcast clouds
# 5        2.30      UZ          light rain
# 6       12.28      ZA       broken clouds
# 7        4.79      RU     overcast clouds
# 8       14.38      RU     overcast clouds
# 9       12.66      US           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_col_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness",
                 "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_col_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Qaanaaq      GL  77.4840  -69.3632      7.03        91          98
# 1       Jamestown      US  42.0970  -79.2353     40.59        89         100
# 2  Cabo San Lucas      MX  22.8909 -109.9124     85.17        67          34
# 3        Wakkanai      JP  45.4094  141.6739     48.42        55         100
# 4          Broome      US  42.2506  -75.8330     48.15        63         100
# 5    Komsomolskiy      UZ  40.4272   71.7189     56.12        76          75
# 6        Saldanha      ZA -33.0117   17.9442     59.05        95          72
# 7      Chokurdakh      RU  70.6333  147.9167      4.37        98          97
# 8       Saskylakh      RU  71.9167  114.0833     18.90        86         100
# 9          Lompoc      US  34.6391 -120.4579     81.79        56           0
#
#    Wind Speed Current Description
# 0        4.05     overcast clouds
# 1       17.27     overcast clouds
# 2        5.21    scattered clouds
# 3       24.79     overcast clouds
# 4        9.22     overcast clouds
# 5        2.30          light rain
# 6       12.28       broken clouds
# 7        4.79     overcast clouds
# 8       14.38     overcast clouds
# 9       12.66           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file ="../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
